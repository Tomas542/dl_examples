# %% [markdown]
# # Домашнее задание. Решение конкурса на kaggle.com
#
# Это домашнее задание посвящено полноценному решению задачи машинного обучения.

# %% [markdown]
# Есть две части этого домашнего задания:
#
# ### Отправить ваши предсказания в Stepik.
# За прохождение определенных порогов будут начисляться баллы. Эта часть оценивается из 5 баллов.
#
# 1) $1.00 \geqslant score \geqslant 0.84$ --- 5 баллов
#
# 2) $0.84 > score \geqslant 0.77$ --- 4 балла
#
# 3) $0.77 > score \geqslant 0.70$ --- 3 балла
#
# 4) $0.70 > score \geqslant 0.65$ --- 2 балла
#
# 5) $0.65 > score \geqslant 0.6$ --- 1 балл
#
# 6) $0.60 > score$ --- 0 баллов
#
# Для этого мы предварительно разделили данные в задании на две части.
# * `train.csv`. На этом наборе данных вам необходимо создать и обучить модель. Подробное описание файла есть в ноутбуке.
# * `test.csv`. В каждой строчке файла `test.csv` указаны признаки тестовых объектов. Предсказания для этого набора необходимо записать в файл submission.csv и сдать в соответствующий шаг на Stepik. Количество попыток ограничено 100 штук.
#
# Отправлять в Stepik вы будете файл с ответами `my_submission.csv`. В этом файле вам необходимо для каждого объекта из датасета предсказать вероятность класса 1. Мы подготовили для вас файл с примером посылки `submission.csv`. Ваш файл должен быть оформлен таким же образом. В ноутбуке есть пример оформления файла посылки. Для отправки файла с предсказаниями на Stepik есть отдельный шаг.
#
# ### Сделать полноценный отчет о вашей работе.
# Опишите, как вы обработали данные, какие модели попробовали и какие результаты получились (максимум 10 баллов). За каждую выполненную часть будет начислено определенное количество баллов. В этом пункте вам необходимо отправить файл в формате .ipynb на Stepik --- для этого в домашнем задании есть отдельный шаг. Этот пункт оценивается из 10 баллов.
#
# **Вторая часть будет проверяться в формате peer-review. Т.е. вашу посылку на Stepik будут проверять 3 других студента, и медианное значение их оценок будет выставлено. Чтобы получить баллы, вам также нужно будет проверить трех других учеников. Это станет доступно после того, как вы сдадите задание сами.**
#
# ### Контест на Kaggle
# Для вашего удобства мы подготовили [контест на Kaggle](https://www.kaggle.com/c/advanced-dls-spring-2021/). Тестирующая система на Kaggle выдает те же баллы, что и Stepik. Мы рекомендуем в качестве основной тестирующей системы использовать именно Kaggle, а затем сдать лучшую посылку на Stepik. Так вы привыкните работать с Kaggle.
#
# Проблема для российских пользователей Kaggle заключается в том, что подтверждение аккаунта по номеру телефона работает с перебоями или не работает вообще. Без подтвержденного номера телефона вы не сможете совершать посылки в kaggle. Если у вас возникла такая проблема, мы советуем следующие шаги:
# * Попробовать зарегистрировать аккаунт с аутентификацией через gmail. В таком случае, аккаунт должен работать без подтверждения номера телефона.
# * Если у вас есть не российский номер, используйте его для верификации аккаунта.
# * Если на номер телефона не приходит смс для верификации аккаунта, обратитесь в службу поддержки kaggle. Они с переменным успехом умеют подтверждать аккаунты вручную.
# * Если все же подтвердить аккаунт и получить доступ к сдаче заданий не удалось, используйте только сдачу в Stepik.
#
# ### Несколько замечаний по выполнению работы
# * Во всех пунктах указания это минимальный набор вещей, которые стоит сделать. Если вы можете сделать какой-то шаг лучше или добавить что-то свое --- дерзайте!
# * Пожалуйста, перед сдачей ноутбука убедитесь, что работа чистая и понятная. Это значительно облегчит проверку и повысит ваши ожидаемые баллы.
# * Если у вас будут проблемы с решением или хочется совета, то пишите в наш чат в телеграме.
#
#
# Данные: [train.csv](https://drive.google.com/file/d/1ERwQ5odiK1Zvi1LtjpkzCMUswYsAX8_K/view?usp=share_link),
# [test.csv](https://drive.google.com/file/d/1fGw_-RFwvn_LEdt91Jq-7A-wzG6mmH8r/view?usp=share_link), [submission.csv](https://drive.google.com/file/d/199Mt4OYZNaelT83U-HGDsEYs2YcUGQ6y/view?usp=share_link).
#
# Если ссылки на данные не работают, их можно скачать [на Kaggle](https://www.kaggle.com/competitions/advanced-dls-spring-2021/data).

# %% [markdown]
# # Как проверять?
#
# Ставьте полный балл, если выполнены все рекомендации или сделано что-то более интересное и сложное. За каждый отсустствующий пункт из рекомендации снижайте 1 балл.
#
# **Если решение верное, но не удовлетворяет вашим эстетическим предпочтениям, за это баллы снижать не нужно.**

# %% [markdown]
# # Метрика
#
# Перед решением любой задачи важно понимать, как будет оцениваться ваше решение. В данном случае мы используем стандартную для задачи классификации метрику ROC-AUC. Ее можно вычислить, используя только предсказанные вероятности и истинные классы без конкретного порога классификации + она раотает даже если классы в данных сильно несбалансированны (примеров одного класса в десятки раз больше примеров длугого). Именно поэтому она очень удобна для соревнований.
#
# Посчитать ее легко:

# %%
from sklearn.metrics import roc_auc_score

y_true = [0, 1, 1, 0, 1]

y_predictions = [0.1, 0.9, 0.4, 0.6, 0.61]

roc_auc_score(y_true, y_predictions)
# Out:
# 0.8333333333333333

# %% [markdown]
# # Первая часть. Исследование

# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Загрузка данных (2 балла)
#
# 1) Посмотрите на случайные строчки.
#
# 2) Посмотрите, есть ли в датасете незаполненные значения (nan'ы) с помощью data.isna() или data.info() и, если нужно, замените их на что-то. Будет хорошо, если вы построите табличку с количеством nan в каждой колонке.

# %%
# !gdown 1ERwQ5odiK1Zvi1LtjpkzCMUswYsAX8_K  # train.csv
# !gdown 1fGw_-RFwvn_LEdt91Jq-7A-wzG6mmH8r  # test.csv
# !gdown 199Mt4OYZNaelT83U-HGDsEYs2YcUGQ6y  # submission.csv
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1ERwQ5odiK1Zvi1LtjpkzCMUswYsAX8_K
# To: /content/train.csv
# 100% 664k/664k [00:00<00:00, 12.8MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1fGw_-RFwvn_LEdt91Jq-7A-wzG6mmH8r
# To: /content/test.csv
# 100% 218k/218k [00:00<00:00, 63.9MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=199Mt4OYZNaelT83U-HGDsEYs2YcUGQ6y
# To: /content/submission.csv
# 100% 14.7k/14.7k [00:00<00:00, 42.8MB/s]

# %%
data = pd.read_csv("./train.csv")

# %%
# Для вашего удобства списки с именами разных колонок

# Числовые признаки
num_cols = ["ClientPeriod", "MonthlySpending", "TotalSpent"]

# Категориальные признаки
cat_cols = [
    "Sex",
    "IsSeniorCitizen",
    "HasPartner",
    "HasChild",
    "HasPhoneService",
    "HasMultiplePhoneNumbers",
    "HasInternetService",
    "HasOnlineSecurityService",
    "HasOnlineBackup",
    "HasDeviceProtection",
    "HasTechSupportAccess",
    "HasOnlineTV",
    "HasMovieSubscription",
    "HasContractPhone",
    "IsBillingPaperless",
    "PaymentMethod",
]

feature_cols = num_cols + cat_cols
target_col = "Churn"

# %%
data.sample(10)
# Out:
#       ClientPeriod  MonthlySpending TotalSpent     Sex  IsSeniorCitizen  \
# 3236            67           105.65     6717.9  Female                0
# 334             44            84.80    3626.35    Male                0
# 2210            15            19.90     320.45  Female                0
# 133             55           100.00     5509.3  Female                1
# 4953            59           106.75     6252.9    Male                0
# 4485            12            54.30      654.5  Female                0
# 4537            11            23.15      245.2    Male                0
# 4103            61            24.10     1551.6  Female                0
# 2365             2            19.90       33.7    Male                0
# 781             72            23.30    1623.15  Female                0
#
#      HasPartner HasChild HasPhoneService HasMultiplePhoneNumbers  \
# 3236        Yes      Yes             Yes                     Yes
# 334         Yes       No             Yes                     Yes
# 2210         No       No             Yes                      No
# 133          No       No             Yes                     Yes
# 4953        Yes       No             Yes                     Yes
# 4485         No       No             Yes                      No
# 4537         No       No             Yes                     Yes
# 4103        Yes      Yes             Yes                     Yes
# 2365         No       No             Yes                      No
# 781         Yes      Yes             Yes                     Yes
#
#      HasInternetService HasOnlineSecurityService      HasOnlineBackup  \
# 3236        Fiber optic                       No                   No
# 334         Fiber optic                      Yes                   No
# 2210                 No      No internet service  No internet service
# 133         Fiber optic                       No                   No
# 4953        Fiber optic                      Yes                  Yes
# 4485                DSL                       No                  Yes
# 4537                 No      No internet service  No internet service
# 4103                 No      No internet service  No internet service
# 2365                 No      No internet service  No internet service
# 781                  No      No internet service  No internet service
#
#       HasDeviceProtection HasTechSupportAccess          HasOnlineTV  \
# 3236                  Yes                  Yes                  Yes
# 334                   Yes                   No                   No
# 2210  No internet service  No internet service  No internet service
# 133                   Yes                   No                  Yes
# 4953                  Yes                  Yes                  Yes
# 4485                   No                  Yes                   No
# 4537  No internet service  No internet service  No internet service
# 4103  No internet service  No internet service  No internet service
# 2365  No internet service  No internet service  No internet service
# 781   No internet service  No internet service  No internet service
#
#      HasMovieSubscription HasContractPhone IsBillingPaperless  \
# 3236                  Yes         Two year                Yes
# 334                    No   Month-to-month                Yes
# 2210  No internet service   Month-to-month                 No
# 133                   Yes         One year                Yes
# 4953                   No   Month-to-month                Yes
# 4485                   No   Month-to-month                Yes
# 4537  No internet service   Month-to-month                 No
# 4103  No internet service         Two year                Yes
# 2365  No internet service   Month-to-month                Yes
# 781   No internet service         One year                Yes
#
#                   PaymentMethod  Churn
# 3236  Bank transfer (automatic)      0
# 334     Credit card (automatic)      0
# 2210               Mailed check      0
# 133            Electronic check      1
# 4953           Electronic check      1
# 4485           Electronic check      0
# 4537    Credit card (automatic)      1
# 4103               Mailed check      0
# 2365    Credit card (automatic)      0
# 781   Bank transfer (automatic)      0

# %%
data.isna().sum()
# Out:
# ClientPeriod                0
# MonthlySpending             0
# TotalSpent                  0
# Sex                         0
# IsSeniorCitizen             0
# HasPartner                  0
# HasChild                    0
# HasPhoneService             0
# HasMultiplePhoneNumbers     0
# HasInternetService          0
# HasOnlineSecurityService    0
# HasOnlineBackup             0
# HasDeviceProtection         0
# HasTechSupportAccess        0
# HasOnlineTV                 0
# HasMovieSubscription        0
# HasContractPhone            0
# IsBillingPaperless          0
# PaymentMethod               0
# Churn                       0
# dtype: int64

# %% [markdown]
# ## Анализ данных (3 балла)
#
# 1) Для численных призанков постройте гистограмму (*plt.hist(...)*) или boxplot (*plt.boxplot(...)*). Для категориальных посчитайте количество каждого значения для каждого признака. Для каждой колонки надо сделать *data.value_counts()* и построить bar диаграммы *plt.bar(...)* или круговые диаграммы *plt.pie(...)* (хорошо, елси вы сможете это сделать на одном гарфике с помощью *plt.subplots(...)*).
#
# 2) Посмотрите на распределение целевой переменной и скажите, являются ли классы несбалансированными.
#
# 3) (Если будет желание) Поиграйте с разными библиотеками для визуализации - *sns*, *pandas_visual_analysis*, etc.
#
# Второй пункт очень важен, потому что существуют задачи классификации с несбалансированными классами. Например, это может значить, что в датасете намного больше примеров 0 класса. В таких случаях нужно 1) не использовать accuracy как метрику 2) использовать методы борьбы с imbalanced dataset (обычно если датасет сильно несбалансирован, т.е. класса 1 в 20 раз меньше класса 0).

# %%
fig, ax = plt.subplots(nrows=1, ncols=3, figsize=(13, 5))
for i in range(len(num_cols)):
    ax[i].hist(data[num_cols[i]])

# %%
fig, ax = plt.subplots(nrows=4, ncols=4, figsize=(14, 14))
for i in range(len(cat_cols)):
    counts = data[cat_cols[i]].value_counts()
    ax[i // 4, i % 4].bar(x=counts.index, height=counts.values)
    ax[i // 4, i % 4].set_title(cat_cols[i])

# %%
# 2
sns.barplot(x=[0, 1], y=data[target_col].value_counts().values, hue=[0, 1])
plt.show()

# %% [markdown]
# (Дополнительно) Если вы нашли какие-то ошибки в данных или выбросы, то можете их убрать. Тут можно поэксперементировать с обработкой данных как угодно, но не за баллы.

# %%
data.columns
# Out:
# Index(['ClientPeriod', 'MonthlySpending', 'TotalSpent', 'Sex',
#        'IsSeniorCitizen', 'HasPartner', 'HasChild', 'HasPhoneService',
#        'HasMultiplePhoneNumbers', 'HasInternetService',
#        'HasOnlineSecurityService', 'HasOnlineBackup', 'HasDeviceProtection',
#        'HasTechSupportAccess', 'HasOnlineTV', 'HasMovieSubscription',
#        'HasContractPhone', 'IsBillingPaperless', 'PaymentMethod', 'Churn'],
#       dtype='object')

# %%
data["PaymentMethod"].value_counts()
# Out:
# PaymentMethod
# Electronic check             1786
# Mailed check                 1194
# Bank transfer (automatic)    1159
# Credit card (automatic)      1143
# Name: count, dtype: int64

# %%
# YOUR CODE
# импостер в виде NaN
data[num_cols[2]] = pd.to_numeric(data[num_cols[2]], errors="coerce")
data = data.fillna({num_cols[2]: data[num_cols[2]].mean()})

# нет сервиса, значит нет и услуги
data = data.replace({"No internet service": "No", "No phone service": "No"})

# делает хуже
# data = data.replace({"Electronic check": "Check",
#                      "Mailed check": "Check",
#                      "Bank transfer (automatic)": "Automatic",
#                      "Credit card (automatic)":"Automatic"})

# %% [markdown]
# ## Применение линейных моделей (3 балла)
#
# 1) Обработайте данные для того, чтобы к ним можно было применить LogisticRegression. Т.е. отнормируйте числовые признаки, а категориальные закодируйте с помощью one-hot-encoding'а.
#
# 2) С помощью кроссвалидации или разделения на train/valid выборку протестируйте разные значения гиперпараметра C и выберите лучший (можно тестировать С=100, 10, 1, 0.1, 0.01, 0.001) по метрике ROC-AUC.
#
# Если вы разделяете на train/valid, то используйте LogisticRegressionCV. Он сам при вызове .fit() подберет параметр С. (не забудьте передать scroing='roc_auc', чтобы при кроссвалидации сравнивались значения этой метрики, и refit=True, чтобы при потом модель обучилась на всем датасете с лучшим параметром C).
#
#
# (более сложный вариант) Если вы будете использовать кроссвалидацию, то преобразования данных и LogisticRegression нужно соединить в один Pipeline с помощью make_pipeline, как это делалось во втором семинаре. Потом pipeline надо передать в GridSearchCV. Для one-hot-encoding'a можно испльзовать комбинацию LabelEncoder + OneHotEncoder (сначала превращаем строчки в числа, а потом числа првращаем в one-hot вектора.)

# %%
from sklearn.linear_model import LogisticRegression, LogisticRegressionCV
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.preprocessing import (
    StandardScaler,
    RobustScaler,
    LabelEncoder,
    OneHotEncoder,
)
from sklearn.pipeline import make_pipeline

from sklearn.compose import ColumnTransformer

# %%
from sklearn.metrics import roc_auc_score

# %%
numeric_transformer = StandardScaler()
categorical_transformer = OneHotEncoder(handle_unknown="ignore", drop="first")
label_encoder = LabelEncoder()

preprocessor = ColumnTransformer(
    transformers=[
        ("num", numeric_transformer, num_cols),
        ("cat2", categorical_transformer, cat_cols),
    ]
)
data[target_col] = label_encoder.fit_transform(data[target_col])

Cs = [1e-3, 1e-2, 1e-1, 1, 1e1, 1e2]
model_grid = LogisticRegression()
model = LogisticRegressionCV(Cs=Cs, cv=5, scoring="roc_auc", refit=True)

pipeline_grid = make_pipeline(preprocessor, model_grid)
pipeline = make_pipeline(preprocessor, model)

X_train, X_val, y_train, y_val = train_test_split(
    data.drop(target_col, axis=1), data[target_col], test_size=0.2, random_state=42
)

params_grid = {"logisticregression__C": Cs}
grid_search = GridSearchCV(pipeline_grid, params_grid, cv=5, scoring="roc_auc")
grid_search.fit(X_train, y_train)
print(
    "GreadSearch roc_auc:",
    roc_auc_score(y_val, grid_search.best_estimator_.predict_proba(X_val)[:, 1:]),
)
print(
    "Best C param from GridSearch:", grid_search.best_params_["logisticregression__C"]
)


pipeline.fit(X_train, y_train)
print(
    "LogisticRegressionCV roc_auc:",
    roc_auc_score(y_val, pipeline.predict_proba(X_val)[:, 1:]),
)
print(
    "Best C param from LogReg:",
    Cs[
        np.argmax(
            np.sum(pipeline.named_steps["logisticregressioncv"].scores_[1], axis=0)
        )
    ],
)
# Out:
# GreadSearch roc_auc: 0.8277537148714917
# Best C param from GridSearch: 10.0
# LogisticRegressionCV roc_auc: 0.8279153314062485
# Best C param from LogReg: 10.0

# %% [markdown]
# Выпишите какое лучшее качество и с какими параметрами вам удалось получить

# %% [markdown]
# ## Применение градиентного бустинга (2 балла)
#
# Если вы хотите получить баллы за точный ответ, то стоит попробовать градиентный бустинг. Часто градиентный бустинг с параметрами по умолчанию даст вам 80% результата за 0% усилий.
#
# Мы будем использовать catboost, поэтому нам не надо кодировать категориальные признаки. Catboost сделает это сам (в .fit() надо передать cat_features=cat_cols). А численные признаки нормировать для моделей, основанных на деревьях не нужно.
#
# 1) Разделите выборку на train/valid. Протестируйте catboost cо стандартными параметрами.
#
# 2) Протестируйте разные занчения параметров количества деревьев и learning_rate'а и выберите лучшую по метрике ROC-AUC комбинацию.
#
# (Дополнительно) Есть некоторые сложности с тем, чтобы использовать CatBoostClassifier вместе с GridSearchCV, поэтому мы не просим использовать кроссвалидацию. Но можете попробовать)

# %%
# YOUR CODE
# !pip install catboost -q

import catboost as cb

cbc = cb.CatBoostClassifier(
    iterations=10,
    cat_features=cat_cols,
    eval_metric="AUC",
    verbose=False,
    random_seed=42,
)

grid = {
    "learning_rate": [1e-3, 1e-2, 1e-1],
    "depth": [4, 6, 8, 10, 12],
    "l2_leaf_reg": [1, 3, 5, 7, 9],
}

X_train, X_val, y_train, y_val = train_test_split(
    data.drop(target_col, axis=1), data[target_col], test_size=0.2, random_state=42
)

scaler = StandardScaler()
X_train[num_cols] = scaler.fit_transform(X_train[num_cols])
X_val[num_cols] = scaler.fit_transform(X_val[num_cols])

cbc.grid_search(
    grid,
    X=X_train,
    y=y_train,
    stratified=True,
    shuffle=True,
    partition_random_seed=42,
    cv=5,
)

roc_auc_score(y_val, cbc.predict_proba(X_val)[:, 1:])
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 98.7/98.7 MB 8.2 MB/s eta 0:00:00
#
# bestTest = 0.8078685048
# bestIteration = 2
#
# Metric AUC is not calculated on train by default. To calculate this metric on train, add hints=skip_train~false to metric parameters.
# 0:	loss: 0.8078685	best: 0.8078685 (0)	total: 97.9ms	remaining: 7.25s
#
# bestTest = 0.813980205
# bestIteration = 8
#
# Metric AUC is not calculated on train by default. To calculate this metric on train, add hints=skip_train~false to metric parameters.
# 1:	loss: 0.8139802	best: 0.8139802 (1)	total: 137ms	remaining: 5s
#
# bestTest = 0.8346376812
# bestIteration = 9
#
# Metric AUC is not calculated on train by default. To calculate this metric on train, add hints=skip_train~false to metric parameters.
# 2:	loss: 0.8346377	best: 0.8346377 (2)	total: 177ms	remaining: 4.24s
#
# bestTest = 0.8180487805
# bestIteration = 7
#
# Metric AUC is not calculated on train by default. To calculate this metric on train, add hints=skip_train~false to metric parameters.
# 3:	loss: 0.8180488	best: 0.8346377 (2)	total: 217ms	remaining: 3.86s
#
# bestTest = 0.8117179215
# bestIteration = 5
#
# Metric AUC is not calculated on train by default. To calculate this metric on train, add hints=skip_train~false to metric parameters.
# 4:	loss: 0.8117179	best: 0.8346377 (2)	total: 258ms	remaining: 3.62s
#
# bestTest = 0.836620714
# bestIteration = 9
#
# Metric AUC is not calculated on train by default. To calculate this metric on train, add hints=skip_train~false to metric parameters.
# 5:	loss: 0.8366207	best: 0.8366207 (5)	total: 303ms	remaining: 3.48s
#
# bestTest = 0.8215411806
# bestIteration = 9
#
# Metric AUC is not calculated on train by default. To calculate this metric on train, add hints=skip_train~false to metric parameters.
# 6:	loss: 0.8215412	best: 0.8366207 (5)	total: 344ms	remaining: 3.34s
#
# bestTest = 0.8214492754
# bestIteration = 9
#
# Metric AUC is not calculated on train by default. To calculate this metric on train, add hints=skip_train~false to metric parameters.
# 7:	loss: 0.8214493	best: 0.8366207 (5)	total: 387ms	remaining: 3.24s
#
# bestTest = 0.8354224107
# bestIteration = 8
#
# Metric AUC is not calculated on train by default. To calculate this metric on train, add hints=skip_train~false to metric parameters.
# 8:	loss: 0.8354224	best: 0.8366207 (5)	total: 429ms	remaining: 3.14s
#
# bestTest = 0.822173913
# bestIteration = 7
#
# Metric AUC is not calculated on train by default. To calculate this metric on train, add hints=skip_train~false to metric parameters.
# 9:	loss: 0.8221739	best: 0.8366207 (5)	total: 471ms	remaining: 3.06s
#
# bestTest = 0.8213432308
# bestIteration = 9
#
# Metric AUC is not calculated on train by default. To calculate this metric on train, add hints=skip_train~false to metric parameters.
# 10:	loss: 0.8213432	best: 0.8366207 (5)	total: 516ms	remaining: 3s
#
# bestTest = 0.8347083775
# bestIteration = 9
#
# Metric AUC is not calculated on train by default. To calculate this metric on train, add hints=skip_train~false to metric parameters.
# 11:	loss: 0.8347084	best: 0.8366207 (5)	total: 558ms	remaining: 2.93s
#
# bestTest = 0.8184164016
# bestIteration = 9
#
# Metric AUC is not calculated on train by default. To calculate this metric on train, add hints=skip_train~false to metric parameters.
# 12:	loss: 0.8184164	best: 0.8366207 (5)	total: 599ms	remaining: 2.85s
#
# bestTest = 0.8120289855
# bestIteration = 5
#
# Metric AUC is not calculated on train by default. To calculate this metric on train, add hints=skip_train~false to metric parameters.
# 13:	loss: 0.8120290	best: 0.8366207 (5)	total: 656ms	remaining: 2.86s
#
# bestTest = 0.8368469424
# bestIteration = 9
#
# Metric AUC is not calculated on train by default. To calculate this metric on train, add hints=skip_train~false to metric parameters.
# 14:	loss: 0.8368469	best: 0.8368469 (14)	total: 712ms	remaining: 2.85s
#
# bestTest = 0.823379286
# bestIteration = 4
#
# Metric AUC is not calculated on train by default. To calculate this metric on train, add hints=skip_train~false to metric parameters.
# 15:	loss: 0.8233793	best: 0.8368469 (14)	total: 783ms	remaining: 2.88s
#
# bestTest = 0.8250936727
# bestIteration = 7
#
# Metric AUC is not calculated on train by default. To calculate this metric on train, add hints=skip_train~false to metric parameters.
# 16:	loss: 0.8250937	best: 0.8368469 (14)	total: 836ms	remaining: 2.85s
#
# bestTest = 0.8370024744
# bestIteration = 9
#
# Metric AUC is not calculated on train by default. To calculate this metric on train, add hints=skip_train~false to metric parameters.
# 17:	loss: 0.8370025	best: 0.8370025 (17)	total: 889ms	remaining: 2.81s
#
# bestTest = 0.8231424532
# bestIteration = 9
#
# Metric AUC is not calculated on train by default. To calculate this metric on train, add hints=skip_train~false to metric parameters.
# 18:	loss: 0.8231425	best: 0.8370025 (17)	total: 940ms	remaining: 2.77s
#
# bestTest = 0.8232838459
# bestIteration = 9
#
# Metric AUC is not calculated on train by default. To calculate this metric on train, add hints=skip_train~false to metric parameters.
# 19:	loss: 0.8232838	best: 0.8370025 (17)	total: 995ms	remaining: 2.74s
#
# bestTest = 0.8359172853
# bestIteration = 9
#
# Metric AUC is not calculated on train by default. To calculate this metric on train, add hints=skip_train~false to metric parameters.
# 20:	loss: 0.8359173	best: 0.8370025 (17)	total: 1.04s	remaining: 2.69s
#
# bestTest = 0.8278296218
# bestIteration = 9
#
# Metric AUC is not calculated on train by default. To calculate this metric on train, add hints=skip_train~false to metric parameters.
# 21:	loss: 0.8278296	best: 0.8370025 (17)	total: 1.1s	remaining: 2.65s
#
# bestTest = 0.8290526688
# bestIteration = 9
#
# Metric AUC is not calculated on train by default. To calculate this metric on train, add hints=skip_train~false to metric parameters.
# 22:	loss: 0.8290527	best: 0.8370025 (17)	total: 1.15s	remaining: 2.6s
#
# bestTest = 0.836019795
# bestIteration = 9
#
# Metric AUC is not calculated on train by default. To calculate this metric on train, add hints=skip_train~false to metric parameters.
# 23:	loss: 0.8360198	best: 0.8370025 (17)	total: 1.21s	remaining: 2.57s
#
# bestTest = 0.826542948
# bestIteration = 4
#
# Metric AUC is not calculated on train by default. To calculate this metric on train, add hints=skip_train~false to metric parameters.
# 24:	loss: 0.8265429	best: 0.8370025 (17)	total: 1.26s	remaining: 2.52s
#
# bestTest = 0.82669848
# bestIteration = 4
#
# Metric AUC is not calculated on train by default. To calculate this metric on train, add hints=skip_train~false to metric parameters.
# 25:	loss: 0.8266985	best: 0.8370025 (17)	total: 1.31s	remaining: 2.47s
#
# bestTest = 0.8390562036
# bestIteration = 9
#
# Metric AUC is not calculated on train by default. To calculate this metric on train, add hints=skip_train~false to metric parameters.
# 26:	loss: 0.8390562	best: 0.8390562 (26)	total: 1.37s	remaining: 2.43s
#
# bestTest = 0.8238741605
# bestIteration = 9
#
# Metric AUC is not calculated on train by default. To calculate this metric on train, add hints=skip_train~false to metric parameters.
# 27:	loss: 0.8238742	best: 0.8390562 (26)	total: 1.43s	remaining: 2.4s
#
# bestTest = 0.8269883351
# bestIteration = 4
#
# Metric AUC is not calculated on train by default. To calculate this metric on train, add hints=skip_train~false to metric parameters.
# 28:	loss: 0.8269883	best: 0.8390562 (26)	total: 1.48s	remaining: 2.35s
#
# bestTest = 0.8389501591
# bestIteration = 9
#
# Metric AUC is not calculated on train by default. To calculate this metric on train, add hints=skip_train~false to metric parameters.
# 29:	loss: 0.8389502	best: 0.8390562 (26)	total: 1.54s	remaining: 2.3s
#
# bestTest = 0.8318168964
# bestIteration = 8
#
# Metric AUC is not calculated on train by default. To calculate this metric on train, add hints=skip_train~false to metric parameters.
# 30:	loss: 0.8318169	best: 0.8390562 (26)	total: 1.62s	remaining: 2.3s
#
# bestTest = 0.8308907741
# bestIteration = 6
#
# Metric AUC is not calculated on train by default. To calculate this metric on train, add hints=skip_train~false to metric parameters.
# 31:	loss: 0.8308908	best: 0.8390562 (26)	total: 1.71s	remaining: 2.3s
#
# bestTest = 0.8382219866
# bestIteration = 9
#
# Metric AUC is not calculated on train by default. To calculate this metric on train, add hints=skip_train~false to metric parameters.
# 32:	loss: 0.8382220	best: 0.8390562 (26)	total: 1.8s	remaining: 2.29s
#
# bestTest = 0.8288299753
# bestIteration = 8
#
# Metric AUC is not calculated on train by default. To calculate this metric on train, add hints=skip_train~false to metric parameters.
# 33:	loss: 0.8288300	best: 0.8390562 (26)	total: 1.88s	remaining: 2.27s
#
# bestTest = 0.8271933545
# bestIteration = 9
#
# Metric AUC is not calculated on train by default. To calculate this metric on train, add hints=skip_train~false to metric parameters.
# 34:	loss: 0.8271934	best: 0.8390562 (26)	total: 1.96s	remaining: 2.24s
#
# bestTest = 0.840950866
# bestIteration = 9
#
# Metric AUC is not calculated on train by default. To calculate this metric on train, add hints=skip_train~false to metric parameters.
# 35:	loss: 0.8409509	best: 0.8409509 (35)	total: 2.03s	remaining: 2.2s
#
# bestTest = 0.8284694238
# bestIteration = 8
#
# Metric AUC is not calculated on train by default. To calculate this metric on train, add hints=skip_train~false to metric parameters.
# 36:	loss: 0.8284694	best: 0.8409509 (35)	total: 2.11s	remaining: 2.16s
#
# bestTest = 0.8298550725
# bestIteration = 8
#
# Metric AUC is not calculated on train by default. To calculate this metric on train, add hints=skip_train~false to metric parameters.
# 37:	loss: 0.8298551	best: 0.8409509 (35)	total: 2.18s	remaining: 2.12s
#
# bestTest = 0.840795334
# bestIteration = 9
#
# Metric AUC is not calculated on train by default. To calculate this metric on train, add hints=skip_train~false to metric parameters.
# 38:	loss: 0.8407953	best: 0.8409509 (35)	total: 2.25s	remaining: 2.07s
#
# bestTest = 0.8296005656
# bestIteration = 7
#
# Metric AUC is not calculated on train by default. To calculate this metric on train, add hints=skip_train~false to metric parameters.
# 39:	loss: 0.8296006	best: 0.8409509 (35)	total: 2.32s	remaining: 2.03s
#
# bestTest = 0.829165783
# bestIteration = 8
#
# Metric AUC is not calculated on train by default. To calculate this metric on train, add hints=skip_train~false to metric parameters.
# 40:	loss: 0.8291658	best: 0.8409509 (35)	total: 2.4s	remaining: 1.99s
#
# bestTest = 0.8431990103
# bestIteration = 9
#
# Metric AUC is not calculated on train by default. To calculate this metric on train, add hints=skip_train~false to metric parameters.
# 41:	loss: 0.8431990	best: 0.8431990 (41)	total: 2.47s	remaining: 1.94s
#
# bestTest = 0.829377872
# bestIteration = 8
#
# Metric AUC is not calculated on train by default. To calculate this metric on train, add hints=skip_train~false to metric parameters.
# 42:	loss: 0.8293779	best: 0.8431990 (41)	total: 2.54s	remaining: 1.89s
#
# bestTest = 0.8287345352
# bestIteration = 8
#
# Metric AUC is not calculated on train by default. To calculate this metric on train, add hints=skip_train~false to metric parameters.
# 43:	loss: 0.8287345	best: 0.8431990 (41)	total: 2.62s	remaining: 1.85s
#
# bestTest = 0.8426334394
# bestIteration = 9
#
# Metric AUC is not calculated on train by default. To calculate this metric on train, add hints=skip_train~false to metric parameters.
# 44:	loss: 0.8426334	best: 0.8431990 (41)	total: 2.69s	remaining: 1.79s
#
# bestTest = 0.8309225875
# bestIteration = 9
#
# Metric AUC is not calculated on train by default. To calculate this metric on train, add hints=skip_train~false to metric parameters.
# 45:	loss: 0.8309226	best: 0.8431990 (41)	total: 2.88s	remaining: 1.81s
#
# bestTest = 0.8270272181
# bestIteration = 9
#
# Metric AUC is not calculated on train by default. To calculate this metric on train, add hints=skip_train~false to metric parameters.
# 46:	loss: 0.8270272	best: 0.8431990 (41)	total: 3.06s	remaining: 1.82s
#
# bestTest = 0.8369423825
# bestIteration = 9
#
# Metric AUC is not calculated on train by default. To calculate this metric on train, add hints=skip_train~false to metric parameters.
# 47:	loss: 0.8369424	best: 0.8431990 (41)	total: 3.22s	remaining: 1.81s
#
# bestTest = 0.8317638742
# bestIteration = 9
#
# Metric AUC is not calculated on train by default. To calculate this metric on train, add hints=skip_train~false to metric parameters.
# 48:	loss: 0.8317639	best: 0.8431990 (41)	total: 3.38s	remaining: 1.79s
#
# bestTest = 0.8412831389
# bestIteration = 9
#
# Metric AUC is not calculated on train by default. To calculate this metric on train, add hints=skip_train~false to metric parameters.
# 49:	loss: 0.8412831	best: 0.8431990 (41)	total: 3.56s	remaining: 1.78s
#
# bestTest = 0.837804878
# bestIteration = 9
#
# Metric AUC is not calculated on train by default. To calculate this metric on train, add hints=skip_train~false to metric parameters.
# 50:	loss: 0.8378049	best: 0.8431990 (41)	total: 3.71s	remaining: 1.75s
#
# bestTest = 0.8335312831
# bestIteration = 9
#
# Metric AUC is not calculated on train by default. To calculate this metric on train, add hints=skip_train~false to metric parameters.
# 51:	loss: 0.8335313	best: 0.8431990 (41)	total: 3.9s	remaining: 1.72s
#
# bestTest = 0.8403852952
# bestIteration = 9
#
# Metric AUC is not calculated on train by default. To calculate this metric on train, add hints=skip_train~false to metric parameters.
# 52:	loss: 0.8403853	best: 0.8431990 (41)	total: 4.07s	remaining: 1.69s
#
# bestTest = 0.8478967833
# bestIteration = 9
#
# Metric AUC is not calculated on train by default. To calculate this metric on train, add hints=skip_train~false to metric parameters.
# 53:	loss: 0.8478968	best: 0.8478968 (53)	total: 4.24s	remaining: 1.65s
#
# bestTest = 0.8333686815
# bestIteration = 9
#
# Metric AUC is not calculated on train by default. To calculate this metric on train, add hints=skip_train~false to metric parameters.
# 54:	loss: 0.8333687	best: 0.8478968 (53)	total: 4.41s	remaining: 1.6s
#
# bestTest = 0.8390632732
# bestIteration = 9
#
# Metric AUC is not calculated on train by default. To calculate this metric on train, add hints=skip_train~false to metric parameters.
# 55:	loss: 0.8390633	best: 0.8478968 (53)	total: 4.59s	remaining: 1.56s
#
# bestTest = 0.8486426299
# bestIteration = 9
#
# Metric AUC is not calculated on train by default. To calculate this metric on train, add hints=skip_train~false to metric parameters.
# 56:	loss: 0.8486426	best: 0.8486426 (56)	total: 4.75s	remaining: 1.5s
#
# bestTest = 0.8327041357
# bestIteration = 9
#
# Metric AUC is not calculated on train by default. To calculate this metric on train, add hints=skip_train~false to metric parameters.
# 57:	loss: 0.8327041	best: 0.8486426 (56)	total: 4.92s	remaining: 1.44s
#
# bestTest = 0.8382644044
# bestIteration = 9
#
# Metric AUC is not calculated on train by default. To calculate this metric on train, add hints=skip_train~false to metric parameters.
# 58:	loss: 0.8382644	best: 0.8486426 (56)	total: 5.11s	remaining: 1.39s
#
# bestTest = 0.8470731707
# bestIteration = 9
#
# Metric AUC is not calculated on train by default. To calculate this metric on train, add hints=skip_train~false to metric parameters.
# 59:	loss: 0.8470732	best: 0.8486426 (56)	total: 5.27s	remaining: 1.32s
#
# bestTest = 0.836387416
# bestIteration = 9
#
# Metric AUC is not calculated on train by default. To calculate this metric on train, add hints=skip_train~false to metric parameters.
# 60:	loss: 0.8363874	best: 0.8486426 (56)	total: 5.89s	remaining: 1.35s
#
# bestTest = 0.840466596
# bestIteration = 9
#
# Metric AUC is not calculated on train by default. To calculate this metric on train, add hints=skip_train~false to metric parameters.
# 61:	loss: 0.8404666	best: 0.8486426 (56)	total: 6.51s	remaining: 1.36s
#
# bestTest = 0.8349840933
# bestIteration = 9
#
# Metric AUC is not calculated on train by default. To calculate this metric on train, add hints=skip_train~false to metric parameters.
# 62:	loss: 0.8349841	best: 0.8486426 (56)	total: 7.07s	remaining: 1.35s
#
# bestTest = 0.8371085189
# bestIteration = 9
#
# Metric AUC is not calculated on train by default. To calculate this metric on train, add hints=skip_train~false to metric parameters.
# 63:	loss: 0.8371085	best: 0.8486426 (56)	total: 7.68s	remaining: 1.32s
#
# bestTest = 0.8388971368
# bestIteration = 9
#
# Metric AUC is not calculated on train by default. To calculate this metric on train, add hints=skip_train~false to metric parameters.
# 64:	loss: 0.8388971	best: 0.8486426 (56)	total: 8.3s	remaining: 1.28s
#
# bestTest = 0.842156239
# bestIteration = 9
#
# Metric AUC is not calculated on train by default. To calculate this metric on train, add hints=skip_train~false to metric parameters.
# 65:	loss: 0.8421562	best: 0.8486426 (56)	total: 8.85s	remaining: 1.21s
#
# bestTest = 0.8378225521
# bestIteration = 9
#
# Metric AUC is not calculated on train by default. To calculate this metric on train, add hints=skip_train~false to metric parameters.
# 66:	loss: 0.8378226	best: 0.8486426 (56)	total: 9.47s	remaining: 1.13s
#
# bestTest = 0.8374620007
# bestIteration = 9
#
# Metric AUC is not calculated on train by default. To calculate this metric on train, add hints=skip_train~false to metric parameters.
# 67:	loss: 0.8374620	best: 0.8486426 (56)	total: 10.2s	remaining: 1.04s
#
# bestTest = 0.8389006716
# bestIteration = 9
#
# Metric AUC is not calculated on train by default. To calculate this metric on train, add hints=skip_train~false to metric parameters.
# 68:	loss: 0.8389007	best: 0.8486426 (56)	total: 11.2s	remaining: 974ms
#
# bestTest = 0.8370943796
# bestIteration = 9
#
# Metric AUC is not calculated on train by default. To calculate this metric on train, add hints=skip_train~false to metric parameters.
# 69:	loss: 0.8370944	best: 0.8486426 (56)	total: 12.2s	remaining: 869ms
#
# bestTest = 0.8365005302
# bestIteration = 9
#
# Metric AUC is not calculated on train by default. To calculate this metric on train, add hints=skip_train~false to metric parameters.
# 70:	loss: 0.8365005	best: 0.8486426 (56)	total: 13.2s	remaining: 742ms
#
# bestTest = 0.8389855072
# bestIteration = 9
#
# Metric AUC is not calculated on train by default. To calculate this metric on train, add hints=skip_train~false to metric parameters.
# 71:	loss: 0.8389855	best: 0.8486426 (56)	total: 13.9s	remaining: 580ms
#
# bestTest = 0.8353022269
# bestIteration = 8
#
# Metric AUC is not calculated on train by default. To calculate this metric on train, add hints=skip_train~false to metric parameters.
# 72:	loss: 0.8353022	best: 0.8486426 (56)	total: 14.5s	remaining: 396ms
#
# bestTest = 0.834330152
# bestIteration = 7
#
# Metric AUC is not calculated on train by default. To calculate this metric on train, add hints=skip_train~false to metric parameters.
# 73:	loss: 0.8343302	best: 0.8486426 (56)	total: 15s	remaining: 202ms
#
# bestTest = 0.8367797808
# bestIteration = 9
#
# Metric AUC is not calculated on train by default. To calculate this metric on train, add hints=skip_train~false to metric parameters.
# 74:	loss: 0.8367798	best: 0.8486426 (56)	total: 15.7s	remaining: 0us
# Estimating final quality...
# Training on fold [0/5]
#
# bestTest = 0.8035595692
# bestIteration = 9
#
# Training on fold [1/5]
#
# bestTest = 0.8619945759
# bestIteration = 9
#
# Training on fold [2/5]
#
# bestTest = 0.8315966179
# bestIteration = 9
#
# Training on fold [3/5]
#
# bestTest = 0.836194019
# bestIteration = 9
#
# Training on fold [4/5]
#
# bestTest = 0.8357168278
# bestIteration = 9
# 0.8011931917880329

# %% [markdown]
# Выпишите, какое лучшее качество и с какими параметрами вам удалось получить

# %% [markdown]
# ВАШ ОТВЕТ

# %% [markdown]
# # Предсказания

# %%
best_model = pipeline  # какая-то предыдущая модель

# %%
X_test = pd.read_csv("./test.csv")
X_test[num_cols[2]] = pd.to_numeric(X_test[num_cols[2]], errors="coerce")
X_test = X_test.fillna({num_cols[2]: X_test[num_cols[2]].mean()})
submission = pd.read_csv("./submission.csv")

submission["Churn"] = best_model.predict_proba(X_test)[
    :, 1:
]  # используйте best_model.predict_proba(X_test), не забудьте выделить вероятность класса 1.
submission.to_csv("./my_submission.csv")

# %%
submission["Churn"].value_counts()

# %% [markdown]
# Лучшее решение отправьте в Stepik.
